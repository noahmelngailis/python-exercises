# %%
import math
import numpy as np

x = range(1, 10)
y1 = [1 for x in x]
y2 = [math.log(x) for x in x]
y3 = [x for x in x] 
y4 = [x * math.log(x) for x in x]
y5 = [x**2 for x in x] 
y6 = [2**x for x in x]
y7 = [math.factorial(x) for x in x] 
y8 = [x**x for x in x]

plt.figure(figsize = (16, 9))
plt.yscale("log")
plt.plot(x, y1, label = "O(1)" )
plt.plot(x, y2, label = "O(log n)")
plt.plot(x, y3, label = "O(n)")
plt.plot(x, y4, label = "O(n log n)")
plt.plot(x, y5, label = "O(n^2)")
plt.plot(x, y6, label = "O(2^n)")
plt.plot(x, y7, label  = "O(n!)")
plt.plot(x, y8, label =  "O(n^n)")
plt.title("Big O Notation")
plt.xlabel("Elements")
plt.ylabel("Operations")
plt.legend()

# %%
import math
x = range(1, 10)
y2 = [math.log(x) for x in x]
plt.table(x, y2, label = "O(log n)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-39920e8764c7> in <module>
#       2 x = range(1, 10)
#       3 y2 = [math.log(x) for x in x]
# ----> 4 plt.table(x, y2, label = "O(log n)")
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in table(cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#    2953         rowColours=rowColours, rowLoc=rowLoc, colLabels=colLabels,
#    2954         colColours=colColours, colLoc=colLoc, loc=loc, bbox=bbox,
# -> 2955         edges=edges, **kwargs)
#    2956
#    2957
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/table.py in table(ax, cellText, cellColours, cellLoc, colWidths, rowLabels, rowColours, rowLoc, colLabels, colColours, colLoc, loc, bbox, edges, **kwargs)
#     753
#     754     rows = len(cellText)
# --> 755     cols = len(cellText[0])
#     756     for row in cellText:
#     757         if len(row) != cols:
#
# TypeError: object of type 'int' has no len()
